# %%
from matplotlib import pyplot as p

# %%
import numpy as np

# %%
x=np.array([10,20])
y=np.array([20,40])

# %%
p.plot(x,y)

# %%
import array as a

# %%
j=np.array([1,2,3,4,5])
k=np.array([5,6,7,8,9])

# %%
p.plot(j,k)

# %%
p.plot(j,k,'d')

# %%
p.plot(j,k,'s')

# %%
p.plot(j,k,marker="s")

# %%
p.plot(j,k,marker="+")

# %%
p.plot(j,k,marker="1")

# %%
e=()
