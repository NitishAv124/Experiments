# %%
import pandas as pd 
import numpy as np

# %%
df1=pd.read_csv("https://github.com/YBIFoundation/Dataset/raw/main/Movies%20Recommendation.csv")

# %%
df1.head()
# Out:
#    Movie_ID      Movie_Title                       Movie_Genre Movie_Language  \
# 0         1       Four Rooms                      Crime Comedy             en
# 1         2        Star Wars  Adventure Action Science Fiction             en
# 2         3     Finding Nemo                  Animation Family             en
# 3         4     Forrest Gump              Comedy Drama Romance             en
# 4         5  American Beauty                             Drama             en
#
#    Movie_Budget  Movie_Popularity Movie_Release_Date  Movie_Revenue  \
# 0       4000000         22.876230         09-12-1995        4300000
# 1      11000000        126.393695         25-05-1977      775398007
# 2      94000000         85.688789         30-05-2003      940335536
# 3      55000000        138.133331         06-07-1994      677945399
# 4      15000000         80.878605         15-09-1999      356296601
#
#    Movie_Runtime  Movie_Vote  ...  \
# 0           98.0         6.5  ...
# ...

# %%
df1.describe()
# Out:
#           Movie_ID  Movie_Budget  Movie_Popularity  Movie_Revenue  \
# count  4760.000000  4.760000e+03       4760.000000   4.760000e+03
# mean   2382.566387  2.920129e+07         21.599510   8.263743e+07
# std    1377.270159  4.075620e+07         31.887919   1.630554e+08
# min       1.000000  0.000000e+00          0.000372   0.000000e+00
# 25%    1190.750000  9.257500e+05          4.807074   0.000000e+00
# 50%    2380.500000  1.500000e+07         13.119058   1.944716e+07
# 75%    3572.250000  4.000000e+07         28.411929   9.341276e+07
# max    4788.000000  3.800000e+08        875.581305   2.787965e+09
#
#        Movie_Runtime   Movie_Vote  Movie_Vote_Count
# count    4758.000000  4760.000000       4760.000000
# mean      107.184111     6.113866        692.508403
# std        21.960332     1.141294       1235.007337
# min         0.000000     0.000000          0.000000
# 25%        94.000000     5.600000         55.000000
# 50%       104.000000     6.200000        238.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Movie_ID                  4760 non-null   int64
#  1   Movie_Title               4760 non-null   object
#  2   Movie_Genre               4760 non-null   object
#  3   Movie_Language            4760 non-null   object
#  4   Movie_Budget              4760 non-null   int64
#  5   Movie_Popularity          4760 non-null   float64
#  6   Movie_Release_Date        4760 non-null   object
#  7   Movie_Revenue             4760 non-null   int64
#  8   Movie_Runtime             4758 non-null   float64
#  9   Movie_Vote                4760 non-null   float64
#  10  Movie_Vote_Count          4760 non-null   int64
#  11  Movie_Homepage            1699 non-null   object
#  12  Movie_Keywords            4373 non-null   object
# ...

# %%
df1.shape
# Out:
# (4760, 21)

# %%
df_features=df1[['Movie_Genre','Movie_Language','Movie_Tagline','Movie_Cast','Movie_Crew','Movie_Director']].fillna('')

# %%
df_features
# Out:
#                            Movie_Genre Movie_Language  \
# 0                         Crime Comedy             en
# 1     Adventure Action Science Fiction             en
# 2                     Animation Family             en
# 3                 Comedy Drama Romance             en
# 4                                Drama             en
# ...                                ...            ...
# 4755                            Horror             en
# 4756               Comedy Family Drama             en
# 4757                    Thriller Drama             en
# 4758                            Family             en
# 4759                       Documentary             en
#
#                                           Movie_Tagline  \
# 0     Twelve outrageous guests. Four scandalous requ...
# 1          A long time ago in a galaxy far, far away...
# 2     There are 3.7 trillion fish in the ocean, they...
# 3     The world will never be the same, once you've ...
# ...

# %%
X = df_features['Movie_Genre']+df_features['Movie_Language']+df_features['Movie_Tagline']+df_features['Movie_Cast']+df_features['Movie_Crew']+df_features['Movie_Director']

# %%
X.shape
# Out:
# (4760,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf= TfidfVectorizer()

# %%
X = tfidf.fit_transform(X)

# %%
X.shape
# Out:
# (4760, 225445)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
Sim =cosine_similarity(X)

# %%
Sim
# Out:
# array([[1.        , 0.48020328, 0.64487963, ..., 0.12241772, 0.        ,
#         0.0783889 ],
#        [0.48020328, 1.        , 0.48891484, ..., 0.08901748, 0.        ,
#         0.05658049],
#        [0.64487963, 0.48891484, 1.        , ..., 0.11648139, 0.        ,
#         0.07721644],
#        ...,
#        [0.12241772, 0.08901748, 0.11648139, ..., 1.        , 0.        ,
#         0.01636636],
#        [0.        , 0.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.0783889 , 0.05658049, 0.07721644, ..., 0.01636636, 0.        ,
#         1.        ]])

# %%
Fav =input('Enter your favourite movie name : ')
# Out:
# Enter your favourite movie name :  Star Wars

# %%
Movie_Names=df['Movie_Title'].tolist()

# %%
import difflib

# %%
Movie_Recommended=difflib.get_close_matches(Fav ,Movie_Names)

# %%
Movie_Recommended
# Out:
# ['Star Wars', 'Star Trek', 'State Fair']

# %%
Nearest=Movie_Recommended[0]

# %%
Nearest
# Out:
# 'Star Wars'

# %%
Indexed=df[df.Movie_Title == Nearest]['Movie_ID'].values[0]

# %%
Indexed
# Out:
# 2

# %%
Recom_Score=list(enumerate(Sim[Indexed]))

# %%
Recom_Score
# Out:
# [(0, 0.6448796289597313),
#  (1, 0.4889148404367986),
#  (2, 0.9999999999999997),
#  (3, 0.6961420322084673),
#  (4, 0.7161643109888772),
#  (5, 0.5731986243401858),
#  (6, 0.7206679391643044),
#  (7, 0.3895998783497765),
#  (8, 0.38984040685327376),
#  (9, 0.7309984366538365),
#  (10, 0.7359634659348333),
#  (11, 0.33266459888522026),
#  (12, 0.572035151136917),
#  (13, 0.5619625942564507),
#  (14, 0.5968863510021075),
#  (15, 0.4256006396963505),
#  (16, 0.5201185222049434),
#  (17, 0.49967234657544857),
#  (18, 0.5463718575862836),
#  (19, 0.412886536782852),
#  (20, 0.674449168530226),
#  (21, 0.41750668275928216),
#  (22, 0.5241391371777203),
#  (23, 0.643735010446963),
#  (24, 0.6509591146843471),
#  (25, 0.42569006457718994),
#  (26, 0.6775229538362433),
#  (27, 0.7424276373725403),
#  (28, 0.5002389380299449),
#  (29, 0.3371176607277242),
#  (30, 0.45687535606428253),
#  (31, 0.5414493539502184),
#  (32, 0.3553214013368371),
#  (33, 0.3147552334693684),
# ...

# %%
len(Recom_Score)
# Out:
# 4760

# %%
Sorted_list= sorted(Recom_Score,key = lambda x:x[1],reverse=True )

# %%
print(Sorted_list)
# Out:
# [(2, 0.9999999999999997), (245, 0.8077697367834197), (189, 0.7798857804167446), (1262, 0.7764310832456587), (392, 0.7744544727295312), (2691, 0.7741246993414642), (3126, 0.7666263201038322), (572, 0.7657964761384903), (1164, 0.7637975493328775), (1140, 0.7619801178244714), (4289, 0.7594062607186989), (1532, 0.7551582126349282), (3507, 0.7548863866087401), (960, 0.7545937092499219), (307, 0.7535155089705609), (4130, 0.7514466790968362), (1118, 0.7510124210981445), (2850, 0.7509398693385025), (4055, 0.7506058859683397), (3492, 0.7505608245626192), (1855, 0.749610453883208), (3840, 0.7491899318715585), (391, 0.7486680935593857), (4181, 0.7484243295231513), (298, 0.7480559658388746), (1129, 0.7473643295437671), (1460, 0.7471704400299645), (3873, 0.7465846163609731), (3131, 0.746188025082852), (3907, 0.7458126150497401), (4046, 0.7456908542206502), (712, 0.744086355965288), (1511, 0.7437199233583451), (4076, 0.7436887432180355), (3130, 0.7434009213335925), (3697, 0.742711020625079), (27, 
# ...

# %%
print('Top  10 movies for you \n')
i=1
for movie in Sorted_list:
    index=movie[0]
    title_from_index=df[df.index==index]['Movie_Title'].values[0]
    if (i<11):
      print(i,'.', title_from_index)
      i+=1
# Out:
# Top  10 movies for you
#
# 1 . Finding Nemo
# 2 . Monsters, Inc.
# 3 . The Day After Tomorrow
# 4 . The Core
# 5 . Toy Story 2
# 6 . Avatar
# 7 . Blade II
# 8 . Captain America: The First Avenger
# 9 . Deep Blue Sea
# 10 . The X Files: I Want to Believe
